# %%
import numpy as np
import pandas as pd
import requests
import xlsxwriter
import math
from scipy import stats
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

# %%
cg.get_coins_markets(vs_currency='usd')
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://assets.coingecko.com/coins/images/1/large/bitcoin.png?1547033579',
#   'current_price': 47033,
#   'market_cap': 889230428003,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 987854165783,
#   'total_volume': 29502634047,
#   'high_24h': 48588,
#   'low_24h': 45741,
#   'price_change_24h': -1555.003402098257,
#   'price_change_percentage_24h': -3.20042,
#   'market_cap_change_24h': -30184013237.938843,
#   'market_cap_change_percentage_24h': -3.28296,
#   'circulating_supply': 18903437.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 69045,
#   'ath_change_percentage': -31.6295,
#   'ath_date': '2021-11-10T14:24:11.849Z',
#   'atl': 67.81,
#   'atl_change_percentage': 69516.50371,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2021-12-17T16:54:16.146Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
# ...
